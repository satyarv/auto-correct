# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file=open('/content/drive/MyDrive/big.txt').read()

# %%
import re
from collections import Counter

# %%
file

# %%
# function to extract all the words from the text file
def words(text):
    return re.findall(r'\w+', text.lower())

# %%
# extracting words from the file
words(file)
# Out:
# ['the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  '15',
#  'in',
#  'our',
#  'series',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'copyright',
#  'laws',
#  'are',
#  'changing',
#  'all',
#  'over',
#  'the',
#  'world',
#  'be',
#  'sure',
#  'to',
#  'check',
#  'the',
#  'copyright',
#  'laws',
#  'for',
#  'your',
#  'country',
#  'before',
#  'downloading',
#  'or',
#  'redistributing',
#  'this',
#  'or',
#  'any',
#  'other',
#  'project',
#  'gutenberg',
#  'ebook',
#  'this',
#  'header',
#  'should',
#  'be',
#  'the',
#  'first',
#  'thing',
#  'seen',
#  'when',
#  'viewing',
#  'this',
#  'project',
#  'gutenberg',
#  'file',
#  'please',
#  'do',
#  'not',
#  'remove',
#  'it',
#  'do',
#  'not',
#  'change',
#  'or',
#  'edit',
#  'the',
#  'header',
#  'without',
#  'written',
#  'permission',
#  'please',
#  'read',
#  'the',
#  'legal',
#  'small',
#  'print',
#  'and',
#  'other',
#  'information',
#  'about',
#  'the',
#  'ebook',
#  'and',
#  'project',
#  'gutenberg',
#  'at',
#  'the',
#  'bottom',
#  'of',
#  'this',
#  'file',
#  'included',
#  'is',
#  'important',
#  'information',
#  'about',
#  'your',
#  'specific',
#  'rights',
#  'and',
#  'restrictions',
#  'in',
#  'how',
#  'the',
#  'file',
#  'may',
#  'be',
#  'used',
#  'you',
#  'can',
#  'also',
#  'find',
#  'out',
#  'about',
#  'how',
#  'to',
#  'make',
#  'a',
#  'donation',
#  'to',
#  'project',
#  'gutenberg',
#  'and',
#  'how',
#  'to',
#  'get',
#  'involved',
#  'welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'free',
#  'plain',
#  'vanilla',
#  'electronic',
#  'texts',
#  'ebooks',
#  'readable',
#  'by',
#  'both',
#  'humans',
#  'and',
#  'by',
#  'computers',
#  'since',
#  '1971',
#  'these',
#  'ebooks',
#  'were',
#  'prepared',
#  'by',
#  'thousands',
#  'of',
#  'volunteers',
#  'title',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'author',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'release',
#  'date',
#  'march',
#  '1999',
#  'ebook',
#  '1661',
#  'most',
#  'recently',
#  'updated',
#  'november',
#  '29',
#  '2002',
#  'edition',
#  '12',
#  'language',
#  'english',
#  'character',
#  'set',
#  'encoding',
#  'ascii',
#  'start',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'additional',
#  'editing',
#  'by',
#  'jose',
#  'menendez',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'contents',
#  'i',
#  'a',
#  'scandal',
#  'in',
#  'bohemia',
#  'ii',
#  'the',
#  'red',
#  'headed',
#  'league',
#  'iii',
#  'a',
#  'case',
#  'of',
#  'identity',
#  'iv',
#  'the',
#  'boscombe',
#  'valley',
#  'mystery',
#  'v',
#  'the',
#  'five',
#  'orange',
#  'pips',
#  'vi',
#  'the',
#  'man',
#  'with',
#  'the',
#  'twisted',
#  'lip',
#  'vii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'blue',
#  'carbuncle',
#  'viii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'speckled',
#  'band',
#  'ix',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'engineer',
#  's',
#  'thumb',
#  'x',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'noble',
#  'bachelor',
#  'xi',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'beryl',
#  'coronet',
#  'xii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'copper',
#  'beeches',
#  'adventure',
#  'i',
#  'a',
#  'scandal',
#  'in',
#  'bohemia',
#  'i',
#  'to',
#  'sherlock',
#  'holmes',
#  'she',
#  'is',
#  'always',
#  'the',
#  'woman',
#  'i',
#  'have',
#  'seldom',
#  'heard',
#  'him',
#  'mention',
#  'her',
#  'under',
#  'any',
#  'other',
#  'name',
#  'in',
#  'his',
#  'eyes',
#  'she',
#  'eclipses',
#  'and',
#  'predominates',
#  'the',
#  'whole',
#  'of',
#  'her',
#  'sex',
#  'it',
#  'was',
#  'not',
#  'that',
#  'he',
#  'felt',
#  'any',
#  'emotion',
#  'akin',
#  'to',
#  'love',
#  'for',
#  'irene',
#  'adler',
#  'all',
#  'emotions',
#  'and',
#  'that',
#  'one',
#  'particularly',
#  'were',
#  'abhorrent',
#  'to',
#  'his',
#  'cold',
#  'precise',
#  'but',
#  'admirably',
#  'balanced',
#  'mind',
#  'he',
#  'was',
#  'i',
#  'take',
#  'it',
#  'the',
#  'most',
#  'perfect',
#  'reasoning',
#  'and',
#  'observing',
#  'machine',
#  'that',
#  'the',
#  'world',
#  'has',
#  'seen',
#  'but',
#  'as',
#  'a',
#  'lover',
#  'he',
#  'would',
#  'have',
#  'placed',
#  'himself',
#  'in',
#  'a',
#  'false',
#  'position',
#  'he',
#  'never',
#  'spoke',
#  'of',
#  'the',
#  'softer',
#  'passions',
#  'save',
#  'with',
#  'a',
#  'gibe',
#  'and',
#  'a',
#  'sneer',
#  'they',
#  'were',
#  'admirable',
#  'things',
#  'for',
#  'the',
#  'observer',
#  'excellent',
#  'for',
#  'drawing',
#  'the',
#  'veil',
#  'from',
#  'men',
#  's',
#  'motives',
#  'and',
#  'actions',
#  'but',
#  'for',
#  'the',
#  'trained',
#  'reasoner',
#  'to',
#  'admit',
#  'such',
#  'intrusions',
#  'into',
#  'his',
#  'own',
#  'delicate',
#  'and',
#  'finely',
#  'adjusted',
#  'temperament',
#  'was',
#  'to',
#  'introduce',
#  'a',
#  'distracting',
#  'factor',
#  'which',
#  'might',
#  'throw',
#  'a',
#  'doubt',
#  'upon',
#  'all',
#  'his',
#  'mental',
#  'results',
#  'grit',
#  'in',
#  'a',
#  'sensitive',
#  'instrument',
#  'or',
#  'a',
#  'crack',
#  'in',
#  'one',
#  'of',
#  'his',
#  'own',
#  'high',
#  'power',
#  'lenses',
#  'would',
#  'not',
#  'be',
#  'more',
#  'disturbing',
#  'than',
#  'a',
#  'strong',
#  'emotion',
#  'in',
#  'a',
#  'nature',
#  'such',
#  'as',
#  'his',
#  'and',
#  'yet',
#  'there',
#  'was',
#  'but',
#  'one',
#  'woman',
#  'to',
#  'him',
#  'and',
#  'that',
#  'woman',
#  'was',
#  'the',
#  'late',
#  'irene',
#  'adler',
#  'of',
#  'dubious',
#  'and',
#  'questionable',
#  'memory',
#  'i',
#  'had',
#  'seen',
#  'little',
#  'of',
#  'holmes',
#  'lately',
#  'my',
#  'marriage',
#  'had',
#  'drifted',
#  'us',
#  'away',
#  'from',
#  'each',
#  'other',
#  'my',
#  'own',
#  'complete',
#  'happiness',
#  'and',
#  'the',
#  'home',
#  'centred',
#  'interests',
#  'which',
#  'rise',
#  'up',
#  'around',
#  'the',
#  'man',
#  'who',
#  'first',
#  'finds',
#  'himself',
#  'master',
#  'of',
#  'his',
#  'own',
#  'establishment',
#  'were',
#  'sufficient',
#  'to',
#  'absorb',
#  'all',
#  'my',
#  'attention',
#  'while',
#  'holmes',
#  'who',
#  'loathed',
#  'every',
#  'form',
#  'of',
#  'society',
#  'with',
#  'his',
#  'whole',
#  'bohemian',
#  'soul',
#  'remained',
#  'in',
#  'our',
#  'lodgings',
#  'in',
#  'baker',
#  'street',
#  'buried',
#  'among',
#  'his',
#  'old',
#  'books',
#  'and',
#  'alternating',
#  'from',
#  'week',
#  'to',
#  'week',
#  'between',
#  'cocaine',
#  'and',
#  'ambition',
#  'the',
#  'drowsiness',
#  'of',
#  'the',
#  'drug',
#  'and',
#  'the',
#  'fierce',
#  'energy',
#  'of',
#  'his',
#  'own',
#  'keen',
#  'nature',
#  'he',
#  'was',
#  'still',
#  'as',
#  'ever',
#  'deeply',
#  'attracted',
#  'by',
#  'the',
#  'study',
#  'of',
#  'crime',
#  'and',
#  'occupied',
#  'his',
#  'immense',
#  'faculties',
#  'and',
#  'extraordinary',
#  'powers',
#  'of',
#  'observation',
#  'in',
#  'following',
#  'out',
#  'those',
#  'clues',
#  'and',
#  'clearing',
#  'up',
#  'those',
#  'mysteries',
#  'which',
#  'had',
#  'been',
#  'abandoned',
#  'as',
#  'hopeless',
#  'by',
#  'the',
#  'official',
#  'police',
#  'from',
#  'time',
#  'to',
#  'time',
#  'i',
#  'heard',
#  'some',
#  'vague',
#  'account',
#  'of',
#  'his',
#  'doings',
#  'of',
#  'his',
#  'summons',
#  'to',
#  'odessa',
#  'in',
#  'the',
#  'case',
#  'of',
#  'the',
#  'trepoff',
#  'murder',
#  'of',
#  'his',
#  'clearing',
#  'up',
#  'of',
#  'the',
#  'singular',
#  'tragedy',
#  'of',
#  'the',
#  'atkinson',
#  'brothers',
#  'at',
#  'trincomalee',
#  'and',
#  'finally',
#  'of',
#  'the',
#  'mission',
#  'which',
#  'he',
#  'had',
#  'accomplished',
#  'so',
#  'delicately',
#  'and',
#  'successfully',
#  'for',
#  'the',
#  'reigning',
#  'family',
#  'of',
#  'holland',
#  'beyond',
#  'these',
#  'signs',
#  'of',
#  'his',
#  'activity',
#  'however',
#  'which',
#  'i',
#  'merely',
#  'shared',
#  'with',
#  'all',
#  'the',
#  'readers',
#  'of',
#  'the',
#  'daily',
#  'press',
#  'i',
#  'knew',
#  'little',
#  'of',
#  'my',
#  'former',
#  'friend',
#  'and',
#  'companion',
#  'one',
#  'night',
#  'it',
#  'was',
#  'on',
#  'the',
#  'twentieth',
#  'of',
#  'march',
#  '1888',
#  'i',
#  'was',
#  'returning',
#  'from',
#  'a',
#  'journey',
#  'to',
#  'a',
#  'patient',
#  'for',
#  'i',
#  'had',
#  'now',
#  'returned',
#  'to',
#  'civil',
#  'practice',
#  'when',
#  'my',
#  'way',
#  'led',
#  'me',
#  'through',
#  'baker',
#  'street',
#  'as',
#  'i',
#  'passed',
#  'the',
#  'well',
#  'remembered',
#  'door',
#  'which',
#  'must',
#  'always',
#  'be',
#  'associated',
#  'in',
#  'my',
#  'mind',
#  'with',
#  'my',
#  'wooing',
#  'and',
#  'with',
#  'the',
#  'dark',
#  'incidents',
#  'of',
#  'the',
#  'study',
#  'in',
#  'scarlet',
#  'i',
#  'was',
#  'seized',
#  'with',
#  'a',
#  'keen',
#  'desire',
#  'to',
#  'see',
#  'holmes',
#  'again',
#  'and',
#  'to',
#  'know',
#  'how',
#  'he',
#  'was',
#  'employing',
#  'his',
#  'extraordinary',
#  'powers',
#  'his',
#  'rooms',
#  'were',
#  'brilliantly',
#  'lit',
#  'and',
#  'even',
#  'as',
#  'i',
#  'looked',
#  'up',
#  'i',
#  'saw',
#  'his',
#  'tall',
#  'spare',
#  'figure',
#  'pass',
#  'twice',
#  'in',
#  'a',
#  'dark',
#  'silhouette',
#  'against',
#  'the',
#  'blind',
#  'he',
#  'was',
#  'pacing',
#  'the',
#  'room',
#  'swiftly',
#  'eagerly',
#  'with',
#  'his',
#  'head',
#  'sunk',
#  'upon',
#  'his',
#  'chest',
#  'and',
#  'his',
#  'hands',
#  'clasped',
#  'behind',
#  'him',
#  'to',
#  'me',
#  'who',
#  'knew',
#  'his',
#  'every',
#  'mood',
#  'and',
#  'habit',
#  'his',
#  'attitude',
#  'and',
#  'manner',
#  'told',
#  'their',
#  'own',
#  'story',
#  'he',
#  'was',
#  'at',
#  'work',
#  'again',
#  'he',
#  'had',
#  'risen',
#  'out',
#  'of',
#  'his',
#  'drug',
#  'created',
#  'dreams',
#  'and',
#  'was',
#  'hot',
#  'upon',
#  'the',
#  'scent',
#  'of',
#  'some',
#  'new',
#  'problem',
#  'i',
#  'rang',
#  'the',
#  'bell',
#  'and',
#  'was',
#  'shown',
#  'up',
#  'to',
#  'the',
#  'chamber',
#  'which',
#  'had',
#  'formerly',
#  'been',
#  'in',
#  'part',
#  'my',
#  'own',
#  'his',
#  'manner',
#  'was',
#  'not',
#  'effusive',
#  'it',
#  'seldom',
#  'was',
#  'but',
#  'he',
#  'was',
#  'glad',
#  'i',
#  'think',
#  'to',
#  'see',
#  'me',
#  'with',
#  'hardly',
#  'a',
#  'word',
#  'spoken',
#  'but',
#  'with',
#  'a',
#  'kindly',
#  'eye',
#  'he',
#  'waved',
#  'me',
#  'to',
#  'an',
#  'armchair',
#  'threw',
#  'across',
#  'his',
#  'case',
#  'of',
#  'cigars',
#  'and',
#  'indicated',
#  'a',
#  'spirit',
#  'case',
#  'and',
#  'a',
#  'gasogene',
#  'in',
#  'the',
#  'corner',
#  'then',
#  'he',
#  'stood',
#  'before',
#  'the',
#  'fire',
#  'and',
#  'looked',
#  'me',
#  'over',
#  'in',
#  'his',
#  'singular',
#  'introspective',
#  'fashion',
#  'wedlock',
#  'suits',
#  'you',
#  'he',
#  'remarked',
#  'i',
#  ...]

# %%
# extracting the words and counting their frequency
WORDS = Counter(words(file))

# %%
# words and their respective frequencies
WORDS
# Out:
# Counter({'the': 79809,
#          'project': 288,
#          'gutenberg': 263,
#          'ebook': 87,
#          'of': 40024,
#          'adventures': 17,
#          'sherlock': 101,
#          'holmes': 467,
#          'by': 6735,
#          'sir': 177,
#          'arthur': 34,
#          'conan': 4,
#          'doyle': 5,
#          '15': 47,
#          'in': 22023,
#          'our': 1065,
#          'series': 128,
#          'copyright': 51,
#          'laws': 233,
#          'are': 3630,
#          'changing': 43,
#          'all': 4143,
#          'over': 1282,
#          'world': 362,
#          'be': 6155,
#          'sure': 123,
#          'to': 28765,
#          'check': 38,
#          'for': 6941,
#          'your': 1279,
#          'country': 423,
#          'before': 1362,
#          'downloading': 5,
#          'or': 5352,
#          'redistributing': 7,
#          'this': 4063,
#          'any': 1203,
#          'other': 1501,
#          'header': 7,
#          'should': 1297,
#          'first': 1174,
#          'thing': 303,
#          'seen': 444,
#          'when': 2920,
#          'viewing': 7,
#          'file': 22,
#          'please': 172,
#          'do': 1503,
#          'not': 6626,
#          'remove': 53,
#          'it': 10681,
#          'change': 150,
#          'edit': 4,
#          'without': 1014,
#          'written': 117,
#          'permission': 52,
#          'read': 219,
#          'legal': 52,
#          'small': 524,
#          'print': 37,
#          'and': 38312,
#          'information': 73,
#          'about': 1497,
#          'at': 6789,
#          'bottom': 42,
#          'included': 43,
#          'is': 9773,
#          'important': 285,
#          'specific': 37,
#          'rights': 166,
#          'restrictions': 23,
#          'how': 1315,
#          'may': 2551,
#          'used': 276,
#          'you': 5622,
#          'can': 1095,
#          'also': 734,
#          'find': 294,
#          'out': 1987,
#          'make': 504,
#          'a': 21124,
#          'donation': 10,
#          'get': 468,
#          'involved': 106,
#          'welcome': 18,
#          'free': 421,
#          'plain': 108,
#          'vanilla': 6,
#          'electronic': 58,
#          'texts': 7,
#          'ebooks': 54,
#          'readable': 13,
#          'both': 529,
#          'humans': 2,
#          'computers': 7,
#          'since': 260,
#          '1971': 4,
#          'these': 1231,
#          'were': 4289,
#          'prepared': 138,
#          'thousands': 93,
#          'volunteers': 22,
#          'title': 39,
#          'author': 29,
#          'release': 28,
#          'date': 48,
#          'march': 134,
#          '1999': 3,
#          '1661': 1,
#          'most': 908,
#          'recently': 30,
#          'updated': 4,
#          'november': 41,
#          '29': 24,
#          '2002': 11,
#          'edition': 21,
#          '12': 50,
#          'language': 61,
#          'english': 210,
#          'character': 174,
#          'set': 325,
#          'encoding': 5,
#          'ascii': 11,
#          'start': 67,
#          'additional': 30,
#          'editing': 6,
#          'jose': 1,
#          'menendez': 1,
#          'contents': 50,
#          'i': 7684,
#          'scandal': 19,
#          'bohemia': 15,
#          'ii': 77,
#          'red': 287,
#          'headed': 37,
#          'league': 53,
#          'iii': 91,
#          'case': 438,
#          'identity': 11,
#          'iv': 55,
#          'boscombe': 16,
#          'valley': 77,
#          'mystery': 39,
#          'v': 51,
#          'five': 279,
#          'orange': 23,
#          'pips': 12,
#          'vi': 37,
#          'man': 1648,
#          'with': 9739,
#          'twisted': 21,
#          'lip': 56,
#          'vii': 34,
#          'adventure': 34,
#          'blue': 143,
#          'carbuncle': 16,
#          'viii': 39,
#          'speckled': 5,
#          'band': 54,
#          'ix': 28,
#          'engineer': 12,
#          's': 5626,
#          'thumb': 51,
#          'x': 128,
#          'noble': 48,
#          'bachelor': 18,
#          'xi': 28,
#          'beryl': 4,
#          'coronet': 29,
#          'xii': 28,
#          'copper': 26,
#          'beeches': 12,
#          'she': 3946,
#          'always': 608,
#          'woman': 323,
#          'have': 3493,
#          'seldom': 76,
#          'heard': 636,
#          'him': 5230,
#          'mention': 46,
#          'her': 5284,
#          'under': 963,
#          'name': 262,
#          'his': 10034,
#          'eyes': 937,
#          'eclipses': 2,
#          'predominates': 3,
#          'whole': 742,
#          'sex': 11,
#          'was': 11410,
#          'that': 12512,
#          'he': 12401,
#          'felt': 697,
#          'emotion': 36,
#          'akin': 14,
#          'love': 484,
#          'irene': 18,
#          'adler': 16,
#          'emotions': 10,
#          'one': 3371,
#          'particularly': 174,
#          'abhorrent': 1,
#          'cold': 256,
#          'precise': 13,
#          'but': 5653,
#          'admirably': 7,
#          'balanced': 6,
#          'mind': 341,
#          'take': 616,
#          'perfect': 39,
#          'reasoning': 41,
#          'observing': 21,
#          'machine': 39,
#          'has': 1603,
#          'as': 8064,
#          'lover': 26,
#          'would': 1953,
#          'placed': 182,
#          'himself': 1158,
#          'false': 63,
#          'position': 432,
#          'never': 593,
#          'spoke': 218,
#          'softer': 10,
#          'passions': 29,
#          'save': 110,
#          'gibe': 2,
#          'sneer': 6,
#          'they': 3938,
#          'admirable': 14,
#          'things': 321,
#          'observer': 13,
#          'excellent': 62,
#          'drawing': 240,
#          'veil': 16,
#          'from': 5689,
#          'men': 1145,
#          'motives': 14,
#          'actions': 77,
#          'trained': 23,
#          'reasoner': 6,
#          'admit': 65,
#          'such': 1436,
#          'intrusions': 1,
#          'into': 2124,
#          'own': 785,
#          'delicate': 54,
#          'finely': 11,
#          'adjusted': 16,
#          'temperament': 5,
#          'introduce': 23,
#          'distracting': 1,
#          'factor': 41,
#          'which': 4842,
#          'might': 536,
#          'throw': 48,
#          'doubt': 152,
#          'upon': 1111,
#          'mental': 37,
#          'results': 227,
#          'grit': 1,
#          'sensitive': 35,
#          'instrument': 35,
#          'crack': 20,
#          'high': 290,
#          'power': 545,
#          'lenses': 1,
#          'more': 1997,
#          'disturbing': 9,
#          'than': 1206,
#          'strong': 168,
#          'nature': 169,
#          'yet': 488,
#          'there': 2972,
#          'late': 164,
#          'dubious': 1,
#          'questionable': 3,
#          'memory': 55,
#          'had': 7383,
#          'little': 1000,
#          'lately': 22,
#          'my': 2249,
#          'marriage': 96,
#          'drifted': 5,
#          'us': 684,
#          'away': 838,
#          'each': 411,
#          'complete': 144,
#          'happiness': 143,
#          'home': 294,
#          'centred': 2,
#          'interests': 118,
#          'rise': 234,
#          'up': 2283,
#          'around': 270,
#          'who': 3050,
#          'finds': 23,
#          'master': 141,
#          'establishment': 40,
#          'sufficient': 75,
#          'absorb': 4,
#          'attention': 191,
#          'while': 768,
#          'loathed': 1,
#          'every': 650,
#          'form': 506,
#          'society': 169,
#          'bohemian': 8,
#          'soul': 168,
#          'remained': 231,
#          'lodgings': 11,
#          'baker': 49,
#          'street': 180,
#          'buried': 20,
#          'among': 451,
#          'old': 1178,
#          'books': 59,
#          'alternating': 2,
#          'week': 95,
#          'between': 648,
#          'cocaine': 4,
#          'ambition': 13,
#          'drowsiness': 4,
#          'drug': 21,
#          'fierce': 12,
#          'energy': 45,
#          'keen': 32,
#          'still': 922,
#          'ever': 274,
#          'deeply': 77,
#          'attracted': 36,
#          'study': 144,
#          'crime': 61,
#          'occupied': 116,
#          'immense': 77,
#          'faculties': 8,
#          'extraordinary': 74,
#          'powers': 149,
#          'observation': 39,
#          'following': 207,
#          'those': 1201,
#          'clues': 3,
#          'clearing': 29,
#          'mysteries': 9,
#          'been': 2599,
#          'abandoned': 72,
#          'hopeless': 17,
#          'official': 91,
#          'police': 94,
#          'time': 1524,
#          'some': 1536,
#          'vague': 39,
#          'account': 177,
#          'doings': 11,
#          'summons': 11,
#          'odessa': 3,
#          'trepoff': 1,
#          'murder': 30,
#          'singular': 36,
#          'tragedy': 9,
#          'atkinson': 1,
#          'brothers': 50,
#          'trincomalee': 1,
#          'finally': 156,
#          'mission': 34,
#          'accomplished': 39,
#          'so': 3017,
#          'delicately': 3,
#          'successfully': 25,
#          'reigning': 3,
#          'family': 210,
#          'holland': 12,
#          'beyond': 225,
#          'signs': 98,
#          'activity': 131,
#          'however': 430,
#          'merely': 189,
#          'shared': 25,
#          'readers': 11,
#          'daily': 44,
#          'press': 79,
#          'knew': 496,
#          'former': 177,
#          'friend': 283,
#          'companion': 81,
#          'night': 384,
#          'on': 6639,
#          'twentieth': 19,
#          '1888': 8,
#          'returning': 68,
#          'journey': 69,
#          'patient': 382,
#          'now': 1697,
#          'returned': 194,
#          'civil': 177,
#          'practice': 95,
#          'way': 859,
#          'led': 196,
#          'me': 1920,
#          'through': 814,
#          'passed': 367,
#          'well': 1198,
#          'remembered': 120,
#          'door': 498,
#          'must': 955,
#          'associated': 196,
#          'wooing': 2,
#          'dark': 181,
#          'incidents': 14,
#          'scarlet': 22,
#          'seized': 114,
#          'desire': 96,
#          'see': 1012,
#          'again': 866,
#          'know': 1048,
#          'employing': 7,
#          'rooms': 86,
#          'brilliantly': 5,
#          'lit': 74,
#          'even': 946,
#          'looked': 760,
#          'saw': 599,
#          'tall': 74,
#          'spare': 27,
#          'figure': 103,
#          'pass': 154,
#          'twice': 84,
#          'silhouette': 1,
#          'against': 660,
#          'blind': 23,
#          'pacing': 26,
#          'room': 960,
#          'swiftly': 38,
#          'eagerly': 39,
#          'head': 725,
#          'sunk': 27,
#          'chest': 81,
#          'hands': 454,
#          'clasped': 11,
#          'behind': 401,
#          'mood': 51,
#          'habit': 55,
#          'attitude': 72,
#          'manner': 135,
#          'told': 490,
#          'their': 2955,
#          'story': 133,
#          'work': 382,
#          'risen': 30,
#          'created': 62,
#          'dreams': 16,
#          'hot': 118,
#          'scent': 17,
#          'new': 1208,
#          'problem': 71,
#          'rang': 29,
#          'bell': 65,
#          'shown': 113,
#          'chamber': 35,
#          'formerly': 77,
#          'part': 703,
#          'effusive': 2,
#          'glad': 150,
#          'think': 557,
#          'hardly': 173,
#          'word': 298,
#          'spoken': 92,
#          'kindly': 86,
#          'eye': 110,
#          'waved': 29,
#          'an': 3421,
#          'armchair': 49,
#          'threw': 96,
#          'across': 220,
#          'cigars': 7,
#          'indicated': 88,
#          'spirit': 167,
#          'gasogene': 1,
#          'corner': 128,
#          'then': 1558,
#          'stood': 383,
#          'fire': 274,
#          'introspective': 3,
#          'fashion': 49,
#          'wedlock': 1,
#          'suits': 8,
#          'remarked': 169,
#          'watson': 83,
#          'put': 435,
#          'seven': 132,
#          'half': 318,
#          'pounds': 26,
#          'answered': 226,
#          'indeed': 139,
#          'thought': 902,
#          'just': 767,
#          'trifle': 11,
#          'fancy': 50,
#          'observe': 37,
#          'did': 1875,
#          'tell': 492,
#          'intended': 58,
#          'go': 905,
#          'harness': 27,
#          'deduce': 14,
#          'getting': 92,
#          'yourself': 162,
#          'very': 1340,
#          'wet': 59,
#          'clumsy': 8,
#          'careless': 14,
#          'servant': 46,
#          'girl': 166,
#          'dear': 449,
#          'said': 3464,
#          'too': 548,
#          'much': 671,
#          'certainly': 119,
#          'burned': 77,
#          'lived': 113,
#          'few': 458,
#          'centuries': 12,
#          'ago': 108,
#          'true': 204,
#          'walk': 75,
#          'thursday': 7,
#          'came': 979,
#          'dreadful': 68,
#          'mess': 10,
#          'changed': 134,
#          'clothes': 62,
#          't': 1318,
#          'imagine': 96,
#          'mary': 705,
#          'jane': 2,
#          'incorrigible': 2,
#          'wife': 367,
#          'given': 364,
#          'notice': 98,
#          'fail': 40,
#          'chuckled': 7,
#          'rubbed': 32,
#          'long': 990,
#          'nervous': 53,
#          'together': 260,
#          'simplicity': 30,
#          'itself': 273,
#          'inside': 43,
#          'left': 834,
#          'shoe': 11,
#          'where': 977,
#          'firelight': 2,
#          'strikes': 19,
#          'leather': 35,
#          'scored': 4,
#          'six': 176,
#          'almost': 325,
#          'parallel': 17,
#          'cuts': 5,
#          'obviously': 38,
#          'caused': 102,
#          'someone': 160,
#          'carelessly': 14,
#          'scraped': 21,
#          'round': 556,
#          'edges': 69,
#          'sole': 69,
#          'order': 404,
#          'crusted': 2,
#          'mud': 36,
#          'hence': 32,
#          'double': 48,
#          'deduction': 12,
#          'vile': 16,
#          'weather': 42,
#          'malignant': 80,
#          'boot': 22,
#          'slitting': 2,
#          'specimen': 14,
#          'london': 76,
#          'slavey': 1,
#          'if': 2371,
#          'gentleman': 99,
#          'walks': 10,
#          'smelling': 5,
#          'iodoform': 42,
#          'black': 235,
#          'mark': 38,
#          'nitrate': 7,
#          'silver': 128,
#          'right': 710,
#          'forefinger': 7,
#          'bulge': 2,
#          'side': 511,
#          'top': 42,
#          'hat': 105,
#          'show': 213,
#          'secreted': 2,
#          'stethoscope': 2,
#          'dull': 73,
#          'pronounce': 9,
#          'active': 93,
#          'member': 50,
#          'medical': 22,
#          'profession': 22,
#          'could': 1700,
#          'help': 230,
#          'laughing': 115,
#          'ease': 44,
#          'explained': 60,
#          'process': 218,
#          'hear': 183,
#          'give': 523,
#          'reasons': 64,
#          'appears': 108,
#          'ridiculously': 1,
#          'simple': 138,
#          'easily': 114,
#          'myself': 227,
#          'though': 650,
#          'successive': 17,
#          'instance': 50,
#          'am': 746,
#          'baffled': 8,
#          'until': 325,
#          'explain': 123,
#          'believe': 183,
#          'good': 744,
#          'yours': 46,
#          'quite': 502,
#          'lighting': 16,
#          'cigarette': 6,
#          'throwing': 46,
#          'down': 1128,
#          'distinction': 19,
#          'clear': 233,
#          'example': 286,
#          'frequently': 218,
#          'steps': 188,
#          'lead': 137,
#          'hall': 83,
#          'often': 443,
#          'hundreds': 48,
#          'times': 232,
#          'many': 609,
#          'don': 581,
#          'observed': 131,
#          'point': 223,
#          'seventeen': 10,
#          'because': 630,
#          'interested': 65,
#          'problems': 70,
#          'enough': 175,
#          'chronicle': 7,
#          'two': 1137,
#          'trifling': 12,
#          'experiences': 11,
#          'sheet': 29,
#          'thick': 77,
#          'pink': 27,
#          'tinted': 9,
#          'notepaper': 2,
#          'lying': 118,
#          'open': 322,
#          'table': 296,
#          'last': 565,
#          'post': 114,
#          'aloud': 28,
#          'note': 115,
#          'undated': 1,
#          'either': 293,
#          'signature': 9,
#          'address': 76,
#          'will': 1577,
#          'call': 197,
#          'quarter': 46,
#          'eight': 128,
#          'o': 257,
#          'clock': 120,
#          'desires': 22,
#          'consult': 19,
#          'matter': 365,
#          'deepest': 15,
#          'moment': 487,
#          'recent': 53,
#          'services': 38,
#          'royal': 111,
#          'houses': 117,
#          'europe': 152,
#          'safely': 11,
#          'trusted': 16,
#          'matters': 136,
#          'importance': 117,
#          'exaggerated': 26,
#          'we': 1906,
#          'quarters': 72,
#          'received': 280,
#          'hour': 157,
#          'amiss': 6,
#          'visitor': 74,
#          'wear': 30,
#          'mask': 12,
#          'what': 3011,
#          'means': 253,
#          'no': 2348,
#          'data': 17,
#          'capital': 144,
#          'mistake': 39,
#          'theorise': 1,
#          'insensibly': 2,
#          'begins': 47,
#          'twist': 14,
#          'facts': 72,
#          'suit': 25,
#          'theories': 21,
#          'instead': 137,
#          'carefully': 72,
#          'examined': 49,
#          'writing': 69,
#          'paper': 177,
#          'wrote': 149,
#          'presumably': 8,
#          'endeavouring': 8,
#          'imitate': 7,
#          'processes': 35,
#          'bought': 55,
#          'crown': 61,
#          'packet': 11,
#          'peculiarly': 14,
#          'stiff': 20,
#          'peculiar': 84,
#          'hold': 114,
#          'light': 277,
#          'large': 481,
#          'e': 115,
#          'g': 50,
#          'p': 66,
#          'woven': 5,
#          'texture': 6,
#          'asked': 777,
#          'maker': 4,
#          'monogram': 4,
#          'rather': 219,
#          'stands': 19,
#          'gesellschaft': 1,
#          'german': 196,
#          'company': 190,
#          'customary': 19,
#          'contraction': 60,
#          'like': 1080,
#          'co': 29,
#          'course': 389,
#          'papier': 1,
#          'eg': 1,
#          'let': 506,
#          'glance': 91,
#          'continental': 46,
#          'gazetteer': 1,
#          'took': 573,
#          'heavy': 139,
#          'brown': 71,
#          'volume': 30,
#          'shelves': 3,
#          'eglow': 1,
#          'eglonitz': 1,
#          'here': 691,
#          'egria': 1,
#          'speaking': 185,
#          'far': 408,
#          'carlsbad': 1,
#          'remarkable': 77,
#          'being': 918,
#          'scene': 49,
#          'death': 329,
#          'wallenstein': 1,
#          'its': 1635,
#          'numerous': 50,
#          'glass': 115,
#          'factories': 29,
#          'mills': 39,
#          'ha': 75,
#          'boy': 169,
#          'sparkled': 5,
#          'sent': 319,
#          'great': 790,
#          'triumphant': 16,
#          'cloud': 30,
#          'made': 1007,
#          'precisely': 24,
#          'construction': 25,
#          'sentence': 26,
#          'frenchman': 102,
#          'russian': 461,
#          'uncourteous': 1,
#          'verbs': 1,
#          'only': 1873,
#          'remains': 73,
#          'therefore': 186,
#          'discover': 28,
#          'wanted': 213,
#          'writes': 20,
#          'prefers': 2,
#          'wearing': 87,
#          'showing': 104,
#          'face': 1125,
#          'comes': 91,
#          'mistaken': 59,
#          'resolve': 14,
#          'doubts': 39,
#          'sharp': 83,
#          'sound': 219,
#          'horses': 262,
#          'hoofs': 24,
#          'grating': 10,
#          'wheels': 47,
#          'curb': 4,
#          'followed': 329,
#          'pull': 23,
#          'whistled': 13,
#          'pair': 40,
#          'yes': 688,
#          'continued': 291,
#          'glancing': 98,
#          'window': 186,
#          'nice': 53,
#          'brougham': 4,
#          'beauties': 2,
#          'hundred': 229,
#          'fifty': 94,
#          'guineas': 3,
#          'apiece': 7,
#          'money': 326,
#          'nothing': 646,
#          'else': 201,
#          'better': 266,
#          'bit': 63,
#          'doctor': 183,
#          'stay': 74,
#          'lost': 224,
#          'boswell': 1,
#          'promises': 15,
#          'interesting': 71,
#          'pity': 75,
#          'miss': 112,
#          'client': 33,
#          'want': 323,
#          'sit': 89,
#          'best': 268,
#          'slow': 65,
#          'step': 139,
#          'stairs': 31,
#          'passage': 110,
#          'paused': 79,
#          'immediately': 182,
#          'outside': 110,
#          'loud': 64,
#          'authoritative': 2,
#          'tap': 10,
#          'come': 934,
#          'entered': 282,
#          'less': 367,
#          'feet': 178,
#          'inches': 16,
#          'height': 36,
#          'limbs': 64,
#          'hercules': 4,
#          'dress': 138,
#          'rich': 92,
#          'richness': 2,
#          'england': 304,
#          'bad': 155,
#          'taste': 23,
#          'bands': 27,
#          'astrakhan': 1,
#          'slashed': 3,
#          'sleeves': 30,
#          'fronts': 1,
#          'breasted': 1,
#          'coat': 172,
#          'deep': 214,
#          'cloak': 62,
#          'thrown': 92,
#          'shoulders': 125,
#          'lined': 32,
#          'flame': 15,
#          'coloured': 21,
#          'silk': 49,
#          'secured': 48,
#          'neck': 201,
#          'brooch': 1,
#          'consisted': 38,
#          'single': 173,
#          'flaming': 8,
#          'boots': 91,
#          'extended': 75,
#          'halfway': 19,
#          'calves': 3,
#          'trimmed': 8,
#          'tops': 3,
#          'fur': 38,
#          'completed': 25,
#          'impression': 67,
#          'barbaric': 2,
#          'opulence': 3,
#          'suggested': 69,
#          'appearance': 135,
#          'carried': 282,
#          'broad': 92,
#          'brimmed': 4,
#          'hand': 834,
#          'wore': 58,
#          'upper': 129,
#          'extending': 35,
#          'past': 223,
#          'cheekbones': 4,
#          'vizard': 1,
#          'apparently': 68,
#          'raised': 212,
#          'lower': 195,
#          'appeared': 197,
#          'hanging': 42,
#          'straight': 124,
#          'chin': 30,
#          'suggestive': 11,
#          'resolution': 56,
#          'pushed': 81,
#          'length': 63,
#          'obstinacy': 7,
#          'harsh': 22,
#          'voice': 462,
#          'strongly': 41,
#          'marked': 138,
#          'accent': 18,
#          'uncertain': 30,
#          'pray': 79,
#          'seat': 170,
#          'colleague': 7,
#          'dr': 48,
#          'occasionally': 89,
#          'cases': 452,
#          'whom': 489,
#          'honour': 16,
#          'count': 748,
#          'von': 11,
#          'kramm': 2,
#          'nobleman': 11,
#          'understand': 412,
#          'discretion': 13,
#          'trust': 68,
#          'extreme': 72,
#          'prefer': 21,
#          'communicate': 15,
#          'alone': 337,
#          'rose': 243,
#          'caught': 90,
#          'wrist': 66,
#          'back': 746,
#          'chair': 135,
#          'none': 110,
#          'say': 755,
#          'anything': 379,
#          'shrugged': 35,
#          'begin': 97,
#          'binding': 18,
#          'absolute': 56,
#          'secrecy': 18,
#          'years': 571,
#          'end': 463,
#          'present': 328,
#          'weight': 70,
#          'influence': 137,
#          'european': 99,
#          'history': 348,
#          'promise': 67,
#          'excuse': 53,
#          'strange': 220,
#          'august': 70,
#          'person': 185,
#          'employs': 2,
#          'wishes': 42,
#          'agent': 25,
#          'unknown': 87,
#          'confess': 36,
#          'once': 569,
#          'called': 450,
#          'exactly': 47,
#          'aware': 52,
#          'dryly': 5,
#          'circumstances': 107,
#          'delicacy': 11,
#          'precaution': 9,
#          'taken': 438,
#          'quench': 3,
#          'grow': 74,
#          'seriously': 63,
#          'compromise': 71,
#          'families': 45,
#          'speak': 255,
#          'plainly': 39,
#          'implicates': 5,
#          ...})

# %%
# vocabulary size
len(WORDS)
# Out:
# 32198

# %% [markdown]
# generating a candate word

# %%
# defining a sample word
word = 'haw'

# %%
# splitting the word into sub-words
splits = []
for i in range(len(word) + 1):
    splits.append((word[:i], word[i:]))

# %%
splits
# Out:
# [('', 'haw'), ('h', 'aw'), ('ha', 'w'), ('haw', '')]

# %%
# all possible letters that will be used to generate candidate words
letters = 'abcdefghijklmnopqrstuvwxyz'

# %%
# generating candidates after insertion of a letter
insertion = []
for sw1, sw2 in splits:
    for c in letters:
        insertion.append(sw1 + c + sw2)

# %%
# candidates after insertion
insertion
# Out:
# ['ahaw',
#  'bhaw',
#  'chaw',
#  'dhaw',
#  'ehaw',
#  'fhaw',
#  'ghaw',
#  'hhaw',
#  'ihaw',
#  'jhaw',
#  'khaw',
#  'lhaw',
#  'mhaw',
#  'nhaw',
#  'ohaw',
#  'phaw',
#  'qhaw',
#  'rhaw',
#  'shaw',
#  'thaw',
#  'uhaw',
#  'vhaw',
#  'whaw',
#  'xhaw',
#  'yhaw',
#  'zhaw',
#  'haaw',
#  'hbaw',
#  'hcaw',
#  'hdaw',
#  'heaw',
#  'hfaw',
#  'hgaw',
#  'hhaw',
#  'hiaw',
#  'hjaw',
#  'hkaw',
#  'hlaw',
#  'hmaw',
#  'hnaw',
#  'hoaw',
#  'hpaw',
#  'hqaw',
#  'hraw',
#  'hsaw',
#  'htaw',
#  'huaw',
#  'hvaw',
#  'hwaw',
#  'hxaw',
#  'hyaw',
#  'hzaw',
#  'haaw',
#  'habw',
#  'hacw',
#  'hadw',
#  'haew',
#  'hafw',
#  'hagw',
#  'hahw',
#  'haiw',
#  'hajw',
#  'hakw',
#  'halw',
#  'hamw',
#  'hanw',
#  'haow',
#  'hapw',
#  'haqw',
#  'harw',
#  'hasw',
#  'hatw',
#  'hauw',
#  'havw',
#  'haww',
#  'haxw',
#  'hayw',
#  'hazw',
#  'hawa',
#  'hawb',
#  'hawc',
#  'hawd',
#  'hawe',
#  'hawf',
#  'hawg',
#  'hawh',
#  'hawi',
#  'hawj',
#  'hawk',
#  'hawl',
#  'hawm',
#  'hawn',
#  'hawo',
#  'hawp',
#  'hawq',
#  'hawr',
#  'haws',
#  'hawt',
#  'hawu',
#  'hawv',
#  'haww',
#  'hawx',
#  'hawy',
#  'hawz']

# %%
# generating candidates after deletion of a letter
deletion = []
for sw1, sw2 in splits:
    if sw2:
        deletion.append(sw1 + sw2[1:])

# %%
deletion
# Out:
# ['aw', 'hw', 'ha']

# %%
# generating candidates after substitution of a letter
substitution = []
for sw1, sw2 in splits:
    if sw2:
        for c in letters:
            substitution.append(sw1 + c + sw2[1:])

# %%
substitution
# Out:
# ['aaw',
#  'baw',
#  'caw',
#  'daw',
#  'eaw',
#  'faw',
#  'gaw',
#  'haw',
#  'iaw',
#  'jaw',
#  'kaw',
#  'law',
#  'maw',
#  'naw',
#  'oaw',
#  'paw',
#  'qaw',
#  'raw',
#  'saw',
#  'taw',
#  'uaw',
#  'vaw',
#  'waw',
#  'xaw',
#  'yaw',
#  'zaw',
#  'haw',
#  'hbw',
#  'hcw',
#  'hdw',
#  'hew',
#  'hfw',
#  'hgw',
#  'hhw',
#  'hiw',
#  'hjw',
#  'hkw',
#  'hlw',
#  'hmw',
#  'hnw',
#  'how',
#  'hpw',
#  'hqw',
#  'hrw',
#  'hsw',
#  'htw',
#  'huw',
#  'hvw',
#  'hww',
#  'hxw',
#  'hyw',
#  'hzw',
#  'haa',
#  'hab',
#  'hac',
#  'had',
#  'hae',
#  'haf',
#  'hag',
#  'hah',
#  'hai',
#  'haj',
#  'hak',
#  'hal',
#  'ham',
#  'han',
#  'hao',
#  'hap',
#  'haq',
#  'har',
#  'has',
#  'hat',
#  'hau',
#  'hav',
#  'haw',
#  'hax',
#  'hay',
#  'haz']

# %%
# generating candidates after transposition of two adjacent letters
transpose = []
for sw1, sw2 in splits:
    if len(sw2) > 1:
        transpose.append(sw1 + sw2[1] + sw2[0] + sw2[2:])

# %%
transpose
# Out:
# ['ahw', 'hwa']

# %%
set(insertion+deletion+substitution+transpose)
# Out:
# {'aaw',
#  'ahaw',
#  'ahw',
#  'aw',
#  'baw',
#  'bhaw',
#  'caw',
#  'chaw',
#  'daw',
#  'dhaw',
#  'eaw',
#  'ehaw',
#  'faw',
#  'fhaw',
#  'gaw',
#  'ghaw',
#  'ha',
#  'haa',
#  'haaw',
#  'hab',
#  'habw',
#  'hac',
#  'hacw',
#  'had',
#  'hadw',
#  'hae',
#  'haew',
#  'haf',
#  'hafw',
#  'hag',
#  'hagw',
#  'hah',
#  'hahw',
#  'hai',
#  'haiw',
#  'haj',
#  'hajw',
#  'hak',
#  'hakw',
#  'hal',
#  'halw',
#  'ham',
#  'hamw',
#  'han',
#  'hanw',
#  'hao',
#  'haow',
#  'hap',
#  'hapw',
#  'haq',
#  'haqw',
#  'har',
#  'harw',
#  'has',
#  'hasw',
#  'hat',
#  'hatw',
#  'hau',
#  'hauw',
#  'hav',
#  'havw',
#  'haw',
#  'hawa',
#  'hawb',
#  'hawc',
#  'hawd',
#  'hawe',
#  'hawf',
#  'hawg',
#  'hawh',
#  'hawi',
#  'hawj',
#  'hawk',
#  'hawl',
#  'hawm',
#  'hawn',
#  'hawo',
#  'hawp',
#  'hawq',
#  'hawr',
#  'haws',
#  'hawt',
#  'hawu',
#  'hawv',
#  'haww',
#  'hawx',
#  'hawy',
#  'hawz',
#  'hax',
#  'haxw',
#  'hay',
#  'hayw',
#  'haz',
#  'hazw',
#  'hbaw',
#  'hbw',
#  'hcaw',
#  'hcw',
#  'hdaw',
#  'hdw',
#  'heaw',
#  'hew',
#  'hfaw',
#  'hfw',
#  'hgaw',
#  'hgw',
#  'hhaw',
#  'hhw',
#  'hiaw',
#  'hiw',
#  'hjaw',
#  'hjw',
#  'hkaw',
#  'hkw',
#  'hlaw',
#  'hlw',
#  'hmaw',
#  'hmw',
#  'hnaw',
#  'hnw',
#  'hoaw',
#  'how',
#  'hpaw',
#  'hpw',
#  'hqaw',
#  'hqw',
#  'hraw',
#  'hrw',
#  'hsaw',
#  'hsw',
#  'htaw',
#  'htw',
#  'huaw',
#  'huw',
#  'hvaw',
#  'hvw',
#  'hw',
#  'hwa',
#  'hwaw',
#  'hww',
#  'hxaw',
#  'hxw',
#  'hyaw',
#  'hyw',
#  'hzaw',
#  'hzw',
#  'iaw',
#  'ihaw',
#  'jaw',
#  'jhaw',
#  'kaw',
#  'khaw',
#  'law',
#  'lhaw',
#  'maw',
#  'mhaw',
#  'naw',
#  'nhaw',
#  'oaw',
#  'ohaw',
#  'paw',
#  'phaw',
#  'qaw',
#  'qhaw',
#  'raw',
#  'rhaw',
#  'saw',
#  'shaw',
#  'taw',
#  'thaw',
#  'uaw',
#  'uhaw',
#  'vaw',
#  'vhaw',
#  'waw',
#  'whaw',
#  'xaw',
#  'xhaw',
#  'yaw',
#  'yhaw',
#  'zaw',
#  'zhaw'}

# %%
# defining a function to generate all the candidates that are 1 edit distance from the original word
def edits1(word):
    # splitting the word into sub-words
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]

    # generating candidates after insertion of a letter
    insertion = [sw1 + c + sw2 for sw1, sw2 in splits for c in letters]

    # generating candidates after deletion of a letter
    deletion = [sw1 + sw2[1:] for sw1, sw2 in splits if sw2]

    # generating candidates after substitution of a letter
    substitution = [sw1 + c + sw2[1:] for sw1, sw2 in splits if sw2 for c in letters]

    # generating candidates after transposition of two adjacent letters
    transpose = [sw1 + sw2[1] + sw2[0] + sw2[2:] for sw1, sw2 in splits if len(sw2) > 1]

    # returning all generated candidates for a word
    return set(deletion + insertion + substitution + transpose)

# %%
# generating candidates for a sample word
edits1('the')
# Out:
# {'ahe',
#  'athe',
#  'bhe',
#  'bthe',
#  'che',
#  'cthe',
#  'dhe',
#  'dthe',
#  'ehe',
#  'ethe',
#  'fhe',
#  'fthe',
#  'ghe',
#  'gthe',
#  'he',
#  'hhe',
#  'hte',
#  'hthe',
#  'ihe',
#  'ithe',
#  'jhe',
#  'jthe',
#  'khe',
#  'kthe',
#  'lhe',
#  'lthe',
#  'mhe',
#  'mthe',
#  'nhe',
#  'nthe',
#  'ohe',
#  'othe',
#  'phe',
#  'pthe',
#  'qhe',
#  'qthe',
#  'rhe',
#  'rthe',
#  'she',
#  'sthe',
#  'tae',
#  'tahe',
#  'tbe',
#  'tbhe',
#  'tce',
#  'tche',
#  'tde',
#  'tdhe',
#  'te',
#  'tee',
#  'teh',
#  'tehe',
#  'tfe',
#  'tfhe',
#  'tge',
#  'tghe',
#  'th',
#  'tha',
#  'thae',
#  'thb',
#  'thbe',
#  'thc',
#  'thce',
#  'thd',
#  'thde',
#  'the',
#  'thea',
#  'theb',
#  'thec',
#  'thed',
#  'thee',
#  'thef',
#  'theg',
#  'theh',
#  'thei',
#  'thej',
#  'thek',
#  'thel',
#  'them',
#  'then',
#  'theo',
#  'thep',
#  'theq',
#  'ther',
#  'thes',
#  'thet',
#  'theu',
#  'thev',
#  'thew',
#  'thex',
#  'they',
#  'thez',
#  'thf',
#  'thfe',
#  'thg',
#  'thge',
#  'thh',
#  'thhe',
#  'thi',
#  'thie',
#  'thj',
#  'thje',
#  'thk',
#  'thke',
#  'thl',
#  'thle',
#  'thm',
#  'thme',
#  'thn',
#  'thne',
#  'tho',
#  'thoe',
#  'thp',
#  'thpe',
#  'thq',
#  'thqe',
#  'thr',
#  'thre',
#  'ths',
#  'thse',
#  'tht',
#  'thte',
#  'thu',
#  'thue',
#  'thv',
#  'thve',
#  'thw',
#  'thwe',
#  'thx',
#  'thxe',
#  'thy',
#  'thye',
#  'thz',
#  'thze',
#  'tie',
#  'tihe',
#  'tje',
#  'tjhe',
#  'tke',
#  'tkhe',
#  'tle',
#  'tlhe',
#  'tme',
#  'tmhe',
#  'tne',
#  'tnhe',
#  'toe',
#  'tohe',
#  'tpe',
#  'tphe',
#  'tqe',
#  'tqhe',
#  'tre',
#  'trhe',
#  'tse',
#  'tshe',
#  'tte',
#  'tthe',
#  'tue',
#  'tuhe',
#  'tve',
#  'tvhe',
#  'twe',
#  'twhe',
#  'txe',
#  'txhe',
#  'tye',
#  'tyhe',
#  'tze',
#  'tzhe',
#  'uhe',
#  'uthe',
#  'vhe',
#  'vthe',
#  'whe',
#  'wthe',
#  'xhe',
#  'xthe',
#  'yhe',
#  'ythe',
#  'zhe',
#  'zthe'}

# %%
# number of generated candidates for a sample word
len(edits1('the'))
# Out:
# 182

# %%
len(edits1('language'))
# Out:
# 442

# %%
def known(words):
    return set(w for w in words if w in WORDS)

# %%
known(edits1('lanugage'))
# Out:
# {'language'}

# %%
known(edits1('the'))
# Out:
# {'he',
#  'she',
#  'te',
#  'th',
#  'the',
#  'thee',
#  'them',
#  'then',
#  'they',
#  'thy',
#  'tie',
#  'toe'}

# %%
sum(WORDS.values())
# Out:
# 1115585

# %%
def P(word, N=sum(WORDS.values())):
    return WORDS[word] / N

# %%
P('the')
# Out:
# 0.07154004401278254

# %%
P('how')
# Out:
# 0.001178753748033543

# %%
def candidates(word):
    return list(known([word])) or list(known(edits1(word))) or [word]

# %%
candidates('lanugage')  # likely typo for 'language'
    # could correct to 'love' or 'leave'
# Out:
# ['language']

# %%
candidates('the')
# Out:
# ['the']

# %%
candidates('lave')
# Out:
# ['lame',
#  'lane',
#  'ave',
#  'late',
#  'lava',
#  'gave',
#  'slave',
#  'wave',
#  'save',
#  'have',
#  'cave',
#  'live',
#  'love',
#  'leave',
#  'dave',
#  'lake',
#  'lace']

# %%
def correction(word):
    return max(candidates(word), key=P)

# %%
correction('lave')  # Picks the best candidate correction
# Out:
# 'have'

# %%
correction('lanuage')  # Picks the best candidate correction
# Out:
# 'language'

# %%
sentence = "how arq you"

# %%
tokens = sentence.split()

# %%
corrected_sentence = []
for i in range(len(tokens)):
    corrected_token = correction(tokens[i])
    corrected_sentence.append(corrected_token)

# %%
corrected_sentence
# Out:
# ['how', 'are', 'you']

# %%
" ".join(corrected_sentence)
# Out:
# 'how are you'

# %%
def sentence_corrector(sentence):
    sentence = sentence.lower()
    tokens = sentence.split()
    corrected_sentence = []
    for i in range(len(tokens)):
        corrected_token = correction(tokens[i])
        corrected_sentence.append(corrected_token)
    return " ".join(corrected_sentence)

# %%
sentence_corrector("how arq you")
# Output: 'how are you'
# Out:
# 'how are you'

# %%
sentence_corrector('natural language processing')
# Out:
# 'natural language processing'

# %%
sentence_corrector('i am diing gret')
# Out:
# 'i am doing great'

# %%
sentence_corrector('are you alrihkt')
# Out:
# 'are you alrihkt'

# %%
sentence_corrector('are you foing to the party')
# Out:
# 'are you going to the party'

# %%
sentence_corrector('this is a big siging for us')
# Out:
# 'this is a big singing for us'

# %%
sentence_corrector('i love how versatile acress she is')
# Out:
# 'i love how versatile across she is'
